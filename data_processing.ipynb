# %%
from pymongo import MongoClient

# %%
client = MongoClient()
db_name = "trading_data"
db = client[db_name]
coll = db["datapoints"]

# %%
coll.find_one()
# Out:
# {'_id': ObjectId('60048c9aee07bbc36a5cbe9f'),
#  'guid': '65502408991c41fda5a71befe7e2e007',
#  'timestamp': '2021,01,17,19,14,34,642633',
#  'data': {'adabtc': {'trades': [{'guid': 'b24eb476d817463dad0194496df8b50a',
#      'trade_id': 47051080,
#      'price': 1.054e-05,
#      'quantity': 321.0,
#      'buy_order_id': 256055108,
#      'sell_order_id': 256055167,
#      'is_limit_buy': True,
#      '_cls': 'Trade'},
#     {'guid': 'b24eb476d817463dad0194496df8b50a',
#      'trade_id': 47051081,
#      'price': 1.054e-05,
#      'quantity': 196.0,
#      'buy_order_id': 256055108,
#      'sell_order_id': 256055168,
#      'is_limit_buy': True,
#      '_cls': 'Trade'},
#     {'guid': 'b24eb476d817463dad0194496df8b50a',
#      'trade_id': 47051082,
#      'price': 1.055e-05,
#      'quantity': 51.0,
#      'buy_order_id': 256055179,
#      'sell_order_id': 256055096,
#      'is_limit_buy': False,
#      '_cls': 'Trade'},
#     {'guid': 'b24eb476d817463dad0194496df8b50a',
# ...
