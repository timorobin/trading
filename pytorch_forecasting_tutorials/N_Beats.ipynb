# %%
import os
import warnings

warnings.filterwarnings("ignore")

os.chdir("../../..")

# %%
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping
import torch

from pytorch_forecasting import Baseline, NBeats, TimeSeriesDataSet
from pytorch_forecasting.data import NaNLabelEncoder
from pytorch_forecasting.data.examples import generate_ar_data
from pytorch_forecasting.metrics import SMAPE

# %%
data = generate_ar_data(seasonality=10.0, timesteps=400, n_series=100, seed=42)
data["static"] = 2
data["date"] = pd.Timestamp("2020-01-01") + pd.to_timedelta(data.time_idx, "D")
data.head()
# Out:
#    series  time_idx     value  static       date
# 0       0         0 -0.000000       2 2020-01-01
# 1       0         1 -0.046501       2 2020-01-02
# 2       0         2 -0.097796       2 2020-01-03
# 3       0         3 -0.144397       2 2020-01-04
# 4       0         4 -0.177954       2 2020-01-05

# %%
# create dataset and dataloaders
max_encoder_length = 60
max_prediction_length = 20

training_cutoff = data["time_idx"].max() - max_prediction_length

context_length = max_encoder_length
prediction_length = max_prediction_length

training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="value",
    categorical_encoders={"series": NaNLabelEncoder().fit(data.series)},
    group_ids=["series"],
    # only unknown variable is "value" - and N-Beats can also not take any additional variables
    time_varying_unknown_reals=["value"],
    max_encoder_length=context_length,
    max_prediction_length=prediction_length,
)

validation = TimeSeriesDataSet.from_dataset(training, data, min_prediction_idx=training_cutoff + 1)
batch_size = 128
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=0)

# %%
actuals.size()
# Out:
# torch.Size([20])

# %%
baseline_predictions.size()
# Out:
# torch.Size([100, 20])

# %%
# calculate baseline absolute error
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
baseline_predictions = Baseline().predict(val_dataloader)
SMAPE()(baseline_predictions, actuals)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-31b44edb01a3> in <module>
#       2 actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
#       3 baseline_predictions = Baseline().predict(val_dataloader)
# ----> 4 SMAPE()(baseline_predictions, actuals)
#
# ~/miniconda3/envs/trading/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/miniconda3/envs/trading/lib/python3.8/site-packages/pytorch_lightning/metrics/metric.py in forward(self, *args, **kwargs)
#     151         # add current step
#     152         with torch.no_grad():
# --> 153             self.update(*args, **kwargs)
#     154         self._forward_cache = None
#     155
#
# ~/miniconda3/envs/trading/lib/python3.8/site-packages/pytorch_lightning/metrics/metric.py in wrapped_func(*args, **kwargs)
#     197         def wrapped_func(*args, **kwargs):
#     198             self._computed = None
# --> 199             return update(*args, **kwargs)
#     200         return wrapped_func
#     201
#
# ~/miniconda3/envs/trading/lib/python3.8/site-packages/pytorch_forecasting/metrics.py in update(self, y_pred, target)
#     306             torch.Tensor: loss as a single number for backpropagation
#     307         """
# --> 308         target, lengths = unpack_sequence(target)
#     309         assert not target.requires_grad
#     310
#
# ~/miniconda3/envs/trading/lib/python3.8/site-packages/pytorch_forecasting/utils.py in unpack_sequence(sequence)
#     230         lengths = lengths.to(sequence.device)
#     231     else:
# --> 232         lengths = torch.ones(sequence.size(0), device=sequence.device, dtype=torch.long) * sequence.size(1)
#     233     return sequence, lengths
#     234
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)

# %%
pl.seed_everything(42)
trainer = pl.Trainer(gpus=0, gradient_clip_val=0.1)
net = NBeats.from_dataset(training, learning_rate=3e-2, weight_decay=1e-2, widths=[32, 512], backcast_loss_ratio=0.1)
# Out:
# GPU available: False, used: False
# TPU available: None, using: 0 TPU cores

# %%
# find optimal learning rate
res = trainer.tuner.lr_find(net, train_dataloader=train_dataloader, val_dataloaders=val_dataloader, min_lr=1e-5)
print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
net.hparams.learning_rate = res.suggestion()
# Out:
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 1.7 M
# -----------------------------------------------
# 1.7 M     Trainable params
# 0         Non-trainable params
# 1.7 M     Total params
# Finding best initial lr: 100%|██████████| 100/100 [00:11<00:00,  8.72it/s]
# suggested learning rate: 0.007079457843841375

# %%
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
trainer = pl.Trainer(
    max_epochs=100,
    gpus=0,
    weights_summary="top",
    gradient_clip_val=0.1,
    callbacks=[early_stop_callback],
    limit_train_batches=30,
)


net = NBeats.from_dataset(
    training,
    learning_rate=4e-3,
    log_interval=10,
    log_val_interval=1,
    weight_decay=1e-2,
    widths=[32, 512],
    backcast_loss_ratio=1.0,
)

trainer.fit(
    net,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# GPU available: False, used: False
# TPU available: None, using: 0 TPU cores
#
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 1.7 M
# -----------------------------------------------
# 1.7 M     Trainable params
# 0         Non-trainable params
# 1.7 M     Total params
# Epoch 0:  97%|█████████▋| 30/31 [00:04<00:00,  7.17it/s, loss=2.52, v_num=0, val_loss=2.8, train_loss_step=2.08]
# Validating: 0it [00:00, ?it/s]
# Epoch 0: 100%|██████████| 31/31 [00:04<00:00,  6.80it/s, loss=2.52, v_num=0, val_loss=1.64, train_loss_step=2.17]
# Epoch 1:  97%|█████████▋| 30/31 [00:04<00:00,  6.96it/s, loss=1.75, v_num=0, val_loss=1.64, train_loss_step=1.58, train_loss_epoch=2.9]
# Validating: 0it [00:00, ?it/s]
# Epoch 1: 100%|██████████| 31/31 [00:04<00:00,  6.61it/s, loss=1.75, v_num=0, val_loss=1.2, train_loss_step=1.61, train_loss_epoch=2.9]
# Epoch 2:  97%|█████████▋| 30/31 [00:04<00:00,  6.66it/s, loss=1.38, v_num=0, val_loss=1.2, train_loss_step=1.37, train_loss_epoch=1.82]
# Validating: 0it [00:00, ?it/s]
# Epoch 2: 100%|██████████| 31/31 [00:04<00:00,  6.24it/s, loss=1.38, v_num=0, val_loss=0.924, train_loss_step=1.3, train_loss_epoch=1.82]
# Epoch 3:  97%|█████████▋| 30/31 [00:05<00:00,  5.70it/s, loss=1.2, v_num=0, val_loss=0.924, train_loss_step=1.13, train_loss_epoch=1.44]
# Validating: 0it [00:00, ?it/s]
# Epoch 3: 100%|██████████| 31/31 [00:05<00:00,  5.42it/s, loss=1.2, v_num=0, val_loss=0.82, train_loss_step=1.08, train_loss_epoch=1.44]
# Epoch 4:  97%|█████████▋| 30/31 [00:05<00:00,  5.55it/s, loss=0.91, v_num=0, val_loss=0.82, train_loss_step=0.867, train_loss_epoch=1.23]
# Validating: 0it [00:00, ?it/s]
# Epoch 4: 100%|██████████| 31/31 [00:05<00:00,  5.35it/s, loss=0.91, v_num=0, val_loss=0.785, train_loss_step=0.844, train_loss_epoch=1.23]
# Epoch 5:  97%|█████████▋| 30/31 [00:04<00:00,  6.65it/s, loss=0.791, v_num=0, val_loss=0.785, train_loss_step=0.793, train_loss_epoch=0.968]
# Validating: 0it [00:00, ?it/s]
# Epoch 5: 100%|██████████| 31/31 [00:04<00:00,  6.29it/s, loss=0.791, v_num=0, val_loss=0.775, train_loss_step=0.772, train_loss_epoch=0.968]
# Epoch 6:  97%|█████████▋| 30/31 [00:04<00:00,  6.75it/s, loss=0.761, v_num=0, val_loss=0.775, train_loss_step=0.746, train_loss_epoch=0.805]
# Validating: 0it [00:00, ?it/s]
# Epoch 6: 100%|██████████| 31/31 [00:04<00:00,  6.39it/s, loss=0.761, v_num=0, val_loss=0.771, train_loss_step=0.752, train_loss_epoch=0.805]
# Epoch 7:  97%|█████████▋| 30/31 [00:04<00:00,  6.76it/s, loss=0.748, v_num=0, val_loss=0.771, train_loss_step=0.731, train_loss_epoch=0.766]
# Validating: 0it [00:00, ?it/s]
# Epoch 7: 100%|██████████| 31/31 [00:04<00:00,  6.43it/s, loss=0.748, v_num=0, val_loss=0.767, train_loss_step=0.724, train_loss_epoch=0.766]
# Epoch 8:  97%|█████████▋| 30/31 [00:04<00:00,  6.02it/s, loss=0.736, v_num=0, val_loss=0.767, train_loss_step=0.754, train_loss_epoch=0.751]
# Validating: 0it [00:00, ?it/s]
# Epoch 8: 100%|██████████| 31/31 [00:05<00:00,  5.73it/s, loss=0.736, v_num=0, val_loss=0.761, train_loss_step=0.719, train_loss_epoch=0.751]
# Epoch 9:  97%|█████████▋| 30/31 [00:04<00:00,  6.28it/s, loss=0.727, v_num=0, val_loss=0.761, train_loss_step=0.719, train_loss_epoch=0.734]
# Validating: 0it [00:00, ?it/s]
# Epoch 9: 100%|██████████| 31/31 [00:05<00:00,  5.89it/s, loss=0.727, v_num=0, val_loss=0.76, train_loss_step=0.743, train_loss_epoch=0.734]
# Epoch 10:  97%|█████████▋| 30/31 [00:04<00:00,  6.57it/s, loss=0.72, v_num=0, val_loss=0.76, train_loss_step=0.725, train_loss_epoch=0.729]
# Validating: 0it [00:00, ?it/s]
# Epoch 10: 100%|██████████| 31/31 [00:05<00:00,  6.17it/s, loss=0.72, v_num=0, val_loss=0.755, train_loss_step=0.714, train_loss_epoch=0.729]
# Epoch 11:  97%|█████████▋| 30/31 [00:05<00:00,  5.85it/s, loss=0.711, v_num=0, val_loss=0.755, train_loss_step=0.713, train_loss_epoch=0.723]
# Validating: 0it [00:00, ?it/s]
# Epoch 11: 100%|██████████| 31/31 [00:05<00:00,  5.57it/s, loss=0.711, v_num=0, val_loss=0.753, train_loss_step=0.698, train_loss_epoch=0.723]
# Epoch 12:  97%|█████████▋| 30/31 [00:04<00:00,  6.49it/s, loss=0.703, v_num=0, val_loss=0.753, train_loss_step=0.687, train_loss_epoch=0.713]
# Validating: 0it [00:00, ?it/s]
# Epoch 12: 100%|██████████| 31/31 [00:05<00:00,  6.19it/s, loss=0.703, v_num=0, val_loss=0.747, train_loss_step=0.699, train_loss_epoch=0.713]
# Epoch 13:  97%|█████████▋| 30/31 [00:04<00:00,  6.92it/s, loss=0.697, v_num=0, val_loss=0.747, train_loss_step=0.701, train_loss_epoch=0.707]
# Validating: 0it [00:00, ?it/s]
# Epoch 13: 100%|██████████| 31/31 [00:04<00:00,  6.57it/s, loss=0.697, v_num=0, val_loss=0.738, train_loss_step=0.706, train_loss_epoch=0.707]
# Epoch 14:  97%|█████████▋| 30/31 [00:04<00:00,  7.02it/s, loss=0.683, v_num=0, val_loss=0.738, train_loss_step=0.665, train_loss_epoch=0.701]
# Validating: 0it [00:00, ?it/s]
# Epoch 14: 100%|██████████| 31/31 [00:04<00:00,  6.66it/s, loss=0.683, v_num=0, val_loss=0.723, train_loss_step=0.692, train_loss_epoch=0.701]
# Epoch 15:  97%|█████████▋| 30/31 [00:05<00:00,  5.98it/s, loss=0.67, v_num=0, val_loss=0.723, train_loss_step=0.663, train_loss_epoch=0.687]
# Validating: 0it [00:00, ?it/s]
# Epoch 15: 100%|██████████| 31/31 [00:05<00:00,  5.39it/s, loss=0.67, v_num=0, val_loss=0.7, train_loss_step=0.656, train_loss_epoch=0.687]
# Epoch 16:  97%|█████████▋| 30/31 [00:04<00:00,  6.53it/s, loss=0.639, v_num=0, val_loss=0.7, train_loss_step=0.617, train_loss_epoch=0.673]
# Validating: 0it [00:00, ?it/s]
# Epoch 16: 100%|██████████| 31/31 [00:04<00:00,  6.21it/s, loss=0.639, v_num=0, val_loss=0.669, train_loss_step=0.646, train_loss_epoch=0.673]
# Epoch 17:  97%|█████████▋| 30/31 [00:04<00:00,  6.56it/s, loss=0.617, v_num=0, val_loss=0.669, train_loss_step=0.605, train_loss_epoch=0.642]
# Validating: 0it [00:00, ?it/s]
# Epoch 17: 100%|██████████| 31/31 [00:04<00:00,  6.23it/s, loss=0.617, v_num=0, val_loss=0.634, train_loss_step=0.615, train_loss_epoch=0.642]
# Epoch 18:  97%|█████████▋| 30/31 [00:04<00:00,  6.88it/s, loss=0.608, v_num=0, val_loss=0.634, train_loss_step=0.6, train_loss_epoch=0.621]
# Validating: 0it [00:00, ?it/s]
# Epoch 18: 100%|██████████| 31/31 [00:04<00:00,  6.50it/s, loss=0.608, v_num=0, val_loss=0.621, train_loss_step=0.592, train_loss_epoch=0.621]
# Epoch 19:  97%|█████████▋| 30/31 [00:05<00:00,  5.72it/s, loss=0.596, v_num=0, val_loss=0.621, train_loss_step=0.607, train_loss_epoch=0.61]
# Validating: 0it [00:00, ?it/s]
# Epoch 19: 100%|██████████| 31/31 [00:05<00:00,  5.55it/s, loss=0.596, v_num=0, val_loss=0.626, train_loss_step=0.63, train_loss_epoch=0.61]
# Epoch 20:  97%|█████████▋| 30/31 [00:04<00:00,  6.86it/s, loss=0.589, v_num=0, val_loss=0.626, train_loss_step=0.58, train_loss_epoch=0.596]
# Validating: 0it [00:00, ?it/s]
# Epoch 20: 100%|██████████| 31/31 [00:04<00:00,  6.48it/s, loss=0.589, v_num=0, val_loss=0.61, train_loss_step=0.588, train_loss_epoch=0.596]
# Epoch 21:  97%|█████████▋| 30/31 [00:05<00:00,  5.78it/s, loss=0.584, v_num=0, val_loss=0.61, train_loss_step=0.611, train_loss_epoch=0.591]
# Validating: 0it [00:00, ?it/s]
# Epoch 21: 100%|██████████| 31/31 [00:05<00:00,  5.57it/s, loss=0.584, v_num=0, val_loss=0.614, train_loss_step=0.603, train_loss_epoch=0.591]
# Epoch 22:  97%|█████████▋| 30/31 [00:04<00:00,  6.13it/s, loss=0.583, v_num=0, val_loss=0.614, train_loss_step=0.594, train_loss_epoch=0.585]
# Validating: 0it [00:00, ?it/s]
# Epoch 22: 100%|██████████| 31/31 [00:05<00:00,  5.88it/s, loss=0.583, v_num=0, val_loss=0.611, train_loss_step=0.59, train_loss_epoch=0.585]
# Epoch 23:  97%|█████████▋| 30/31 [00:04<00:00,  6.48it/s, loss=0.58, v_num=0, val_loss=0.611, train_loss_step=0.595, train_loss_epoch=0.584]
# Validating: 0it [00:00, ?it/s]
# Epoch 23: 100%|██████████| 31/31 [00:05<00:00,  6.18it/s, loss=0.58, v_num=0, val_loss=0.6, train_loss_step=0.573, train_loss_epoch=0.584]
# Epoch 24:  97%|█████████▋| 30/31 [00:04<00:00,  6.83it/s, loss=0.581, v_num=0, val_loss=0.6, train_loss_step=0.596, train_loss_epoch=0.582]
# Validating: 0it [00:00, ?it/s]
# Epoch 24: 100%|██████████| 31/31 [00:04<00:00,  6.56it/s, loss=0.581, v_num=0, val_loss=0.612, train_loss_step=0.581, train_loss_epoch=0.582]
# Epoch 25:  97%|█████████▋| 30/31 [00:04<00:00,  6.86it/s, loss=0.576, v_num=0, val_loss=0.612, train_loss_step=0.562, train_loss_epoch=0.581]
# Validating: 0it [00:00, ?it/s]
# Epoch 25: 100%|██████████| 31/31 [00:04<00:00,  6.59it/s, loss=0.576, v_num=0, val_loss=0.613, train_loss_step=0.57, train_loss_epoch=0.581]
# Epoch 26:  97%|█████████▋| 30/31 [00:04<00:00,  6.91it/s, loss=0.572, v_num=0, val_loss=0.613, train_loss_step=0.582, train_loss_epoch=0.578]
# Validating: 0it [00:00, ?it/s]
# Epoch 26: 100%|██████████| 31/31 [00:04<00:00,  6.59it/s, loss=0.572, v_num=0, val_loss=0.622, train_loss_step=0.582, train_loss_epoch=0.578]
# Epoch 27:  97%|█████████▋| 30/31 [00:05<00:00,  5.99it/s, loss=0.573, v_num=0, val_loss=0.622, train_loss_step=0.573, train_loss_epoch=0.572]
# Validating: 0it [00:00, ?it/s]
# Epoch 27: 100%|██████████| 31/31 [00:05<00:00,  5.81it/s, loss=0.573, v_num=0, val_loss=0.62, train_loss_step=0.572, train_loss_epoch=0.572]
# Epoch 28:  97%|█████████▋| 30/31 [00:04<00:00,  6.43it/s, loss=0.577, v_num=0, val_loss=0.62, train_loss_step=0.571, train_loss_epoch=0.574]
# Validating: 0it [00:00, ?it/s]
# Epoch 28: 100%|██████████| 31/31 [00:05<00:00,  6.20it/s, loss=0.577, v_num=0, val_loss=0.601, train_loss_step=0.586, train_loss_epoch=0.574]
# Epoch 29:  97%|█████████▋| 30/31 [00:04<00:00,  6.98it/s, loss=0.579, v_num=0, val_loss=0.601, train_loss_step=0.582, train_loss_epoch=0.58]
# Validating: 0it [00:00, ?it/s]
# Epoch 29: 100%|██████████| 31/31 [00:04<00:00,  6.71it/s, loss=0.579, v_num=0, val_loss=0.603, train_loss_step=0.575, train_loss_epoch=0.58]
# Epoch 30:  97%|█████████▋| 30/31 [00:04<00:00,  7.01it/s, loss=0.583, v_num=0, val_loss=0.603, train_loss_step=0.592, train_loss_epoch=0.578]
# Validating: 0it [00:00, ?it/s]
# Epoch 30: 100%|██████████| 31/31 [00:04<00:00,  6.73it/s, loss=0.583, v_num=0, val_loss=0.603, train_loss_step=0.589, train_loss_epoch=0.578]
# Epoch 31:  97%|█████████▋| 30/31 [00:04<00:00,  6.77it/s, loss=0.575, v_num=0, val_loss=0.603, train_loss_step=0.577, train_loss_epoch=0.58]
# Validating: 0it [00:00, ?it/s]
# Epoch 31: 100%|██████████| 31/31 [00:04<00:00,  6.52it/s, loss=0.575, v_num=0, val_loss=0.602, train_loss_step=0.574, train_loss_epoch=0.58]
# Epoch 32:  97%|█████████▋| 30/31 [00:04<00:00,  6.53it/s, loss=0.568, v_num=0, val_loss=0.602, train_loss_step=0.583, train_loss_epoch=0.575]
# Validating: 0it [00:00, ?it/s]
# Epoch 32: 100%|██████████| 31/31 [00:04<00:00,  6.27it/s, loss=0.568, v_num=0, val_loss=0.601, train_loss_step=0.556, train_loss_epoch=0.575]
# Epoch 33:  97%|█████████▋| 30/31 [00:04<00:00,  6.50it/s, loss=0.575, v_num=0, val_loss=0.601, train_loss_step=0.575, train_loss_epoch=0.568]
# Validating: 0it [00:00, ?it/s]
# Epoch 33: 100%|██████████| 31/31 [00:05<00:00,  6.17it/s, loss=0.575, v_num=0, val_loss=0.599, train_loss_step=0.595, train_loss_epoch=0.568]
# Epoch 34:  97%|█████████▋| 30/31 [00:04<00:00,  6.87it/s, loss=0.564, v_num=0, val_loss=0.599, train_loss_step=0.553, train_loss_epoch=0.573]
# Validating: 0it [00:00, ?it/s]
# Epoch 34: 100%|██████████| 31/31 [00:04<00:00,  6.60it/s, loss=0.564, v_num=0, val_loss=0.605, train_loss_step=0.567, train_loss_epoch=0.573]
# Epoch 35:  97%|█████████▋| 30/31 [00:04<00:00,  6.21it/s, loss=0.566, v_num=0, val_loss=0.605, train_loss_step=0.568, train_loss_epoch=0.563]
# Validating: 0it [00:00, ?it/s]
# Epoch 35: 100%|██████████| 31/31 [00:05<00:00,  5.94it/s, loss=0.566, v_num=0, val_loss=0.599, train_loss_step=0.557, train_loss_epoch=0.563]
# Epoch 36:  97%|█████████▋| 30/31 [00:04<00:00,  6.99it/s, loss=0.566, v_num=0, val_loss=0.599, train_loss_step=0.554, train_loss_epoch=0.565]
# Validating: 0it [00:00, ?it/s]
# Epoch 36: 100%|██████████| 31/31 [00:04<00:00,  6.64it/s, loss=0.566, v_num=0, val_loss=0.596, train_loss_step=0.554, train_loss_epoch=0.565]
# Epoch 37:  97%|█████████▋| 30/31 [00:04<00:00,  7.10it/s, loss=0.566, v_num=0, val_loss=0.596, train_loss_step=0.574, train_loss_epoch=0.565]
# Validating: 0it [00:00, ?it/s]
# Epoch 37: 100%|██████████| 31/31 [00:04<00:00,  6.78it/s, loss=0.566, v_num=0, val_loss=0.598, train_loss_step=0.577, train_loss_epoch=0.565]
# Epoch 38:  97%|█████████▋| 30/31 [00:04<00:00,  7.00it/s, loss=0.563, v_num=0, val_loss=0.598, train_loss_step=0.558, train_loss_epoch=0.566]
# Validating: 0it [00:00, ?it/s]
# Epoch 38: 100%|██████████| 31/31 [00:04<00:00,  6.71it/s, loss=0.563, v_num=0, val_loss=0.602, train_loss_step=0.557, train_loss_epoch=0.566]
# Epoch 39:  97%|█████████▋| 30/31 [00:04<00:00,  7.05it/s, loss=0.568, v_num=0, val_loss=0.602, train_loss_step=0.578, train_loss_epoch=0.564]
# Validating: 0it [00:00, ?it/s]
# Epoch 39: 100%|██████████| 31/31 [00:04<00:00,  6.75it/s, loss=0.568, v_num=0, val_loss=0.616, train_loss_step=0.573, train_loss_epoch=0.564]
# Epoch 40:  97%|█████████▋| 30/31 [00:04<00:00,  7.05it/s, loss=0.57, v_num=0, val_loss=0.616, train_loss_step=0.563, train_loss_epoch=0.567]
# Validating: 0it [00:00, ?it/s]
# Epoch 40: 100%|██████████| 31/31 [00:04<00:00,  6.76it/s, loss=0.57, v_num=0, val_loss=0.603, train_loss_step=0.574, train_loss_epoch=0.567]
# Epoch 41:  97%|█████████▋| 30/31 [00:04<00:00,  7.03it/s, loss=0.566, v_num=0, val_loss=0.603, train_loss_step=0.577, train_loss_epoch=0.57]
# Validating: 0it [00:00, ?it/s]
# Epoch 41: 100%|██████████| 31/31 [00:04<00:00,  6.74it/s, loss=0.566, v_num=0, val_loss=0.598, train_loss_step=0.595, train_loss_epoch=0.57]
# Epoch 42:  97%|█████████▋| 30/31 [00:04<00:00,  7.08it/s, loss=0.56, v_num=0, val_loss=0.598, train_loss_step=0.555, train_loss_epoch=0.565]
# Validating: 0it [00:00, ?it/s]
# Epoch 42: 100%|██████████| 31/31 [00:04<00:00,  6.77it/s, loss=0.56, v_num=0, val_loss=0.597, train_loss_step=0.568, train_loss_epoch=0.565]
# Epoch 43:  97%|█████████▋| 30/31 [00:04<00:00,  6.96it/s, loss=0.568, v_num=0, val_loss=0.597, train_loss_step=0.583, train_loss_epoch=0.562]
# Validating: 0it [00:00, ?it/s]
# Epoch 43: 100%|██████████| 31/31 [00:04<00:00,  6.68it/s, loss=0.568, v_num=0, val_loss=0.596, train_loss_step=0.567, train_loss_epoch=0.562]
# Epoch 44:  97%|█████████▋| 30/31 [00:04<00:00,  6.99it/s, loss=0.56, v_num=0, val_loss=0.596, train_loss_step=0.548, train_loss_epoch=0.567]
# Validating: 0it [00:00, ?it/s]
# Epoch 44: 100%|██████████| 31/31 [00:04<00:00,  6.69it/s, loss=0.56, v_num=0, val_loss=0.599, train_loss_step=0.567, train_loss_epoch=0.567]
# Epoch 45:  97%|█████████▋| 30/31 [00:04<00:00,  6.05it/s, loss=0.578, v_num=0, val_loss=0.599, train_loss_step=0.603, train_loss_epoch=0.559]
# Validating: 0it [00:00, ?it/s]
# Epoch 45: 100%|██████████| 31/31 [00:05<00:00,  5.85it/s, loss=0.578, v_num=0, val_loss=0.596, train_loss_step=0.585, train_loss_epoch=0.559]
# Epoch 46:  97%|█████████▋| 30/31 [00:04<00:00,  7.05it/s, loss=0.562, v_num=0, val_loss=0.596, train_loss_step=0.565, train_loss_epoch=0.572]
# Validating: 0it [00:00, ?it/s]
# Epoch 46: 100%|██████████| 31/31 [00:04<00:00,  6.76it/s, loss=0.562, v_num=0, val_loss=0.605, train_loss_step=0.563, train_loss_epoch=0.572]
# Epoch 46: 100%|██████████| 31/31 [00:04<00:00,  6.72it/s, loss=0.562, v_num=0, val_loss=0.605, train_loss_step=0.563, train_loss_epoch=0.572]
# 1

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_model = NBeats.load_from_checkpoint(best_model_path)

# %%
best_model_path
# Out:
# '/Users/timrobin/Documents/lightning_logs/version_0/checkpoints/epoch=36-step=1109.ckpt'

# %%
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_model.predict(val_dataloader)
(actuals - predictions).abs().mean()
# Out:
# tensor(3.2458)

# %%
raw_predictions, x = best_model.predict(val_dataloader, mode="raw", return_x=True)

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True);

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_interpretation(x, raw_predictions, idx=idx);
